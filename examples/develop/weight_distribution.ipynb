# %% [markdown]
# # 策略持仓权重分布分析
# ---

# %%
# 导入绘图模块和生成数据
import czsc
from plot_weight import plot_weight_histogram_kde, plot_weight_cdf, plot_absolute_position_analysis

# 生成模拟数据
dfw = czsc.mock.generate_klines_with_weights()
dfw = dfw[['dt', 'symbol', 'weight']].copy()

print("数据准备完成，开始分析...")
# Out:
# 2025-11-14 22:49:10.837 | INFO     | czsc.core:<module>:42 - 使用 rust 版本对象
# C:\Users\zengb\.czsc 目录缓存超过1GB，请适当清理。调用 czsc.empty_cache_path() 可以直接清空缓存
# 2025-11-14 22:49:12.220 | INFO     | czsc.utils.cache:is_found:74 - 缓存文件已找到, C:\Users\zengb\.czsc\generate_klines\387FD5BE_generate_klines.pkl
# 2025-11-14 22:49:12.221 | INFO     | czsc.utils.cache:get:85 - 正在读取缓存记录，地址：C:\Users\zengb\.czsc\generate_klines\387FD5BE_generate_klines.pkl
# 数据准备完成，开始分析...

# %%
# 显示时序曲线图 - 多头累计、空头累计、绝对仓位、净仓位
print("📊 显示时序曲线图...")
plot_absolute_position_analysis(dfw)
# Out:
# 📊 显示时序曲线图...
